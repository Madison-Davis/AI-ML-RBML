# %%
# Imports
# Link 1: https://www.geeksforgeeks.org/apriori-algorithm/?ref=lbp
# Link 2: https://www.geeksforgeeks.org/apriori-algorithm/?ref=lbp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install apyori
from apyori import apriori

# %%
# Data
# Dataset: https://www.kaggle.com/datasets/irfanasrullah/groceries
dataFile = "//content//drive//MyDrive//Coding//Personal Projects//1: Artificial Intelligence//Resources//MarketBasketTransactions.csv"
data = pd.read_csv(dataFile)
data = data.values.tolist()
allTransactions = []
for row in data:
  singleTransaction = []
  for item in range(1, len(row)): # row 1 is not needed
    if str(row[item]) == "nan":
      break
    else:
      singleTransaction.append(row[item])
  allTransactions.append(singleTransaction)

# %%
# Apiori Algorithm

associationRules = apriori(allTransactions, min_support = 0.002, min_confidence = 0.5, min_length = 2)
ruleList = list(associationRules)
ruleList = pd.DataFrame(ruleList)
ruleListSample = ruleList.head(10)
print(ruleListSample)
# Out:
#                                                items   support  \
# 0                        (whole milk, baking powder)  0.009253
# 1                              (whole milk, cereals)  0.003660
# 2                                  (whole milk, jam)  0.002949
# 3                           (other vegetables, rice)  0.003965
# 4               (specialty cheese, other vegetables)  0.004270
# 5                                 (whole milk, rice)  0.004677
# 6      (baking powder, rolls/buns, other vegetables)  0.002135
# 7  (root vegetables, baking powder, other vegetab...  0.002542
# 8  (baking powder, whipped/sour cream, other vege...  0.002440
# 9      (whole milk, baking powder, other vegetables)  0.004372
#
#                                   ordered_statistics
# 0  [((baking powder), (whole milk), 0.52298850574...
# 1  [((cereals), (whole milk), 0.6428571428571428,...
# 2  [((jam), (whole milk), 0.5471698113207547, 2.1...
# 3  [((rice), (other vegetables), 0.52, 2.68744088...
# 4  [((specialty cheese), (other vegetables), 0.5,...
# 5  [((rice), (whole milk), 0.6133333333333333, 2....
# 6  [((baking powder, rolls/buns), (other vegetabl...
# 7  [((root vegetables, baking powder), (other veg...
# 8  [((baking powder, whipped/sour cream), (other ...
# 9  [((baking powder, other vegetables), (whole mi...
